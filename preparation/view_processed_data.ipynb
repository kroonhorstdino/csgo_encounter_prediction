# %%
import pandas as pd
from pathlib import Path
import sys
import numpy as np

sys.path.insert(0, str(Path.cwd() / 'preparation/'))

import data_loader

# %%
pd.options.display.max_rows = 999

df = pd.read_hdf('training_data\data_chunk_0_0.h5', mode='r')
sample_column = np.random.choice(data_loader.get_die_within_seconds_column_names())


df = df[sample_column]
mask = df == 2
df = df[mask]
print(df.head(100))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-b8f50df86be0> in <module>
#       1 pd.options.display.max_rows = 999
#       2
# ----> 3 df = pd.read_hdf('training_data\data_chunk_0_0.h5', mode='r')
#       4 sample_column = np.random.choice(data_loader.get_die_within_seconds_column_names())
#       5
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\io\pytables.py in read_hdf(path_or_buf, key, mode, **kwargs)
#     382             )
#     383
# --> 384         store = HDFStore(path_or_buf, mode=mode, **kwargs)
#     385         # can't auto open/close if we are using an iterator
#     386         # so delegate to the iterator
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\io\pytables.py in __init__(self, path, mode, complevel, complib, fletcher32, **kwargs)
# ...
